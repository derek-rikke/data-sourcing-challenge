# %% [markdown]
# ### Import Required Libraries and Set Up Environment Variables

# %%
# Dependencies
import requests
import time
from dotenv import load_dotenv
import os
import pandas as pd
import json

# %%
# Set environment variables from the .env in the local environment
load_dotenv('example.env')

nyt_api_key = os.getenv("NYT_API_KEY")
tmdb_api_key = os.getenv("TMDB_API_KEY")

# %% [markdown]
# ### Access the New York Times API

# %%
# Set the base URL
url = "https://api.nytimes.com/svc/search/v2/articlesearch.json?"

# Filter for movie reviews with "love" in the headline
# section_name should be "Movies"
# type_of_material should be "Review"
filter_query = 'section_name:"Movies" AND type_of_material:"Review" AND headline:"love"'

# Use a sort filter, sort by newest
sort = "newest"

# Select the following fields to return:
# headline, web_url, snippet, source, keywords, pub_date, byline, word_count
field_list = "headline,web_url,snippet,source,keywords,pub_date,byline,word_count"

# Search for reviews published between a begin and end date
begin_date = "20130101"
end_date = "20230531"

# Build URL
query_url = (
    f"{url}api-key={nyt_api_key}&fq={filter_query}&fl={field_list}"
    + f"&begin_date={begin_date}&end_date={end_date}&sort={sort}")

# %%
articles = requests.get(query_url).json()
articles_list = articles["response"]["docs"]
print(json.dumps(articles_list, indent=4))
# Out:
# [
#     {
#         "web_url": "https://www.nytimes.com/2023/05/25/movies/the-attachment-diaries-review.html",
#         "snippet": "A gynecologist and her patient form a horrifyingly twisted connection in this batty, bloody Argentine melodrama.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "\u2018The Attachment Diaries\u2019 Review: Love, Sick",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": "The Attachment Diaries",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "The Attachment Diaries (Movie)",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Diment, Valentin Javier",
#                 "rank": 3,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2023-05-25T11:00:03+0000",
#         "byline": {
#             "original": "By Jeannette Catsoulis",
#             "person": [
#                 {
#                     "firstname": "Jeannette",
#                     "middlename": null,
#                     "lastname": "Catsoulis",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 295
#     },
#     {
#         "web_url": "https://www.nytimes.com/2023/05/04/movies/whats-love-got-to-do-with-it-review.html",
#         "snippet": "Two childhood friends navigate cultural differences in this pleasantly uncontentious romantic comedy.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "Review: \u2018What\u2019s Love Got to Do With It?\u2019 Probably a Lot",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": "What\u2019s Love Got to Do With It?",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Kapur, Shekhar",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "James, Lily",
#                 "rank": 3,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Azmi, Shabana",
#                 "rank": 4,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Thompson, Emma",
#                 "rank": 5,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2023-05-04T17:16:45+0000",
#         "byline": {
#             "original": "By Jeannette Catsoulis",
#             "person": [
#                 {
#                     "firstname": "Jeannette",
#                     "middlename": null,
#                     "lastname": "Catsoulis",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 287
#     },
#     {
#         "web_url": "https://www.nytimes.com/2023/05/04/movies/you-can-live-forever-review.html",
#         "snippet": "Religion comes between two girls falling in love in the 1990s in this sweet coming-of-age film bathed in grunge hues.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "\u2018You Can Live Forever\u2019 Review: Do You Love Me Now?",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": "You Can Live Forever",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "You Can Live Forever (Movie)",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Slutsky, Mark",
#                 "rank": 3,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Watts, Sarah (Film Director)",
#                 "rank": 4,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "O'Driscoll, Anwen",
#                 "rank": 5,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Laporte, June (Actor)",
#                 "rank": 6,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2023-05-04T11:00:08+0000",
#         "byline": {
#             "original": "By Elisabeth Vincentelli",
#             "person": [
#                 {
#                     "firstname": "Elisabeth",
#                     "middlename": null,
#                     "lastname": "Vincentelli",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 294
#     },
#     {
#         "web_url": "https://www.nytimes.com/2023/04/21/movies/a-tourists-guide-to-love-review.html",
#         "snippet": "Rachael Leigh Cook stars in this bland rom-com as a travel executive exploring Vietnam and getting over a breakup.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "\u2018A Tourist\u2019s Guide to Love\u2019 Review: A Wearyingly Familiar Trip",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": "A Tourist\u2019s  Guide to Love",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "A Tourist's Guide to Love (Movie)",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Tsuchida, Steven",
#                 "rank": 3,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Cook, Rachael Leigh",
#                 "rank": 4,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2023-04-21T07:03:25+0000",
#         "byline": {
#             "original": "By Elisabeth Vincentelli",
#             "person": [
#                 {
#                     "firstname": "Elisabeth",
#                     "middlename": null,
#                     "lastname": "Vincentelli",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 276
#     },
#     {
#         "web_url": "https://www.nytimes.com/2023/04/20/movies/other-peoples-children-review.html",
#         "snippet": "A radiant Virginie Efira stars as a Parisian teacher who blissfully falls for a man and his 4-year-old daughter, complicating everyone\u2019s lives.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "\u2018Other People\u2019s Children\u2019 Review: True Romance",
#             "kicker": "Critic\u2019s pick",
#             "content_kicker": null,
#             "print_headline": "Intoxicating Love With a Sobering Turn",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Zlotowski, Rebecca",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "Other People's Children (Movie)",
#                 "rank": 3,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2023-04-20T15:35:13+0000",
#         "byline": {
#             "original": "By Manohla Dargis",
#             "person": [
#                 {
#                     "firstname": "Manohla",
#                     "middlename": null,
#                     "lastname": "Dargis",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 801
#     },
#     {
#         "web_url": "https://www.nytimes.com/2023/04/13/movies/one-true-loves-movie-review.html",
#         "snippet": "A film adaptation of Taylor Jenkins Reid\u2019s novel has potential for drama, but it stumbles on stock melodrama.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "\u2018One True Loves\u2019 Review: A Romance Lost at Sea",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": "One True Loves",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Bracey, Luke (1989- )",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Liu, Simu",
#                 "rank": 3,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Reid, Taylor Jenkins",
#                 "rank": 4,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Soo, Phillipa",
#                 "rank": 5,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Fickman, Andy",
#                 "rank": 6,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "One True Loves (Movie)",
#                 "rank": 7,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2023-04-13T11:00:06+0000",
#         "byline": {
#             "original": "By Brandon Yu",
#             "person": [
#                 {
#                     "firstname": "Brandon",
#                     "middlename": null,
#                     "lastname": "Yu",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 320
#     },
#     {
#         "web_url": "https://www.nytimes.com/2023/04/13/movies/the-lost-weekend-a-love-story-review.html",
#         "snippet": "There\u2019s not much Lennon music heard in this doc about his affair with May Pang, and given how much Pang trashes his wife, Yoko Ono, it\u2019s no surprise it was withheld.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "\u2018The Lost Weekend: A Love Story\u2019 Review: When John Lennon Strayed",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": "The Lost Weekend:  A Love Story",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Documentary Films and Programs",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "The Lost Weekend: A Love Story (Movie)",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Pang, May",
#                 "rank": 3,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Lennon, John",
#                 "rank": 4,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Ono, Yoko",
#                 "rank": 5,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Brandstein, Eve",
#                 "rank": 6,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Kaufman, Richard S (Filmmaker)",
#                 "rank": 7,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Samuels, Stuart (Filmmaker)",
#                 "rank": 8,
#                 "major": "N"
#             },
#             {
#                 "name": "subject",
#                 "value": "Content Type: Personal Profile",
#                 "rank": 9,
#                 "major": "N"
#             },
#             {
#                 "name": "subject",
#                 "value": "Pop and Rock Music",
#                 "rank": 10,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2023-04-13T11:00:03+0000",
#         "byline": {
#             "original": "By Glenn Kenny",
#             "person": [
#                 {
#                     "firstname": "Glenn",
#                     "middlename": null,
#                     "lastname": "Kenny",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 327
#     },
#     {
#         "web_url": "https://www.nytimes.com/2023/03/30/movies/a-thousand-and-one-review.html",
#         "snippet": "A mesmerizing Teyana Taylor stars in A.V. Rockwell\u2019s feature directing debut, about motherhood and survival in a fast-changing city.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "\u2018A Thousand and One\u2019 Review: A New York Love Story",
#             "kicker": "Critic\u2019s Pick",
#             "content_kicker": null,
#             "print_headline": "An Unbending Will Meets a Shifting City",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "A Thousand and One (Movie)",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Rockwell, AV (Film Director)",
#                 "rank": 3,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Taylor, Teyana (1990- )",
#                 "rank": 4,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2023-03-30T18:53:42+0000",
#         "byline": {
#             "original": "By Manohla Dargis",
#             "person": [
#                 {
#                     "firstname": "Manohla",
#                     "middlename": null,
#                     "lastname": "Dargis",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 971
#     },
#     {
#         "web_url": "https://www.nytimes.com/2023/02/09/movies/your-place-or-mine-review.html",
#         "snippet": "This humdrum Netflix romantic comedy features Reese Witherspoon and Ashton Kutcher as longtime friends with possibly hidden feelings for each other.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "\u2018Your Place or Mine\u2019 Review: Try Neither",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": "They Have a Humdrum Kind of Love",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "Your Place or Mine (Movie)",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Witherspoon, Reese",
#                 "rank": 3,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Kutcher, Ashton",
#                 "rank": 4,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "McKenna, Aline Brosh",
#                 "rank": 5,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2023-02-10T00:00:05+0000",
#         "byline": {
#             "original": "By Amy Nicholson",
#             "person": [
#                 {
#                     "firstname": "Amy",
#                     "middlename": null,
#                     "lastname": "Nicholson",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 569
#     },
#     {
#         "web_url": "https://www.nytimes.com/2023/02/02/movies/love-in-the-time-of-fentanyl-review.html",
#         "snippet": "To combat the overdose crisis, a group that includes former and current users open a safe consumption site where shooting up does not have to mean death.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "\u2018Love in the Time of Fentanyl\u2019 Review: Heartbreak, Death and Hope in Vancouver",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": "Love in the Time Of Fentanyl",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Documentary Films and Programs",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "subject",
#                 "value": "Fentanyl",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "subject",
#                 "value": "Drug Abuse and Traffic",
#                 "rank": 3,
#                 "major": "N"
#             },
#             {
#                 "name": "subject",
#                 "value": "Volunteers and Community Service",
#                 "rank": 4,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "Love in the Time of Fentanyl (Movie)",
#                 "rank": 5,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Askey, Colin",
#                 "rank": 6,
#                 "major": "N"
#             },
#             {
#                 "name": "glocations",
#                 "value": "Vancouver (British Columbia)",
#                 "rank": 7,
#                 "major": "N"
#             },
#             {
#                 "name": "organizations",
#                 "value": "Overdose Prevention Society",
#                 "rank": 8,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2023-02-02T12:00:11+0000",
#         "byline": {
#             "original": "By Concepci\u00f3n de Le\u00f3n",
#             "person": [
#                 {
#                     "firstname": "Concepci\u00f3n",
#                     "middlename": null,
#                     "lastname": "de Le\u00f3n",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 306
#     }
# ]

# %%
# Create an empty list to store the reviews
reviews_list = []

# loop through pages 0-19 (takes 4:13)
for page in range(0,20):
    # create query with a page number
    # API results show 10 articles at a time
    #original url
    query_url = (
    f"{url}api-key={nyt_api_key}&fq={filter_query}&fl={field_list}"
    + f"&begin_date={begin_date}&end_date={end_date}&sort={sort}")
    #loop through each page
    query_url = f"{query_url}&page={str(page)}"
    # Make a "GET" request and retrieve the JSON
    reviews = requests.get(query_url).json()
    
    # Add a twelve second interval between queries to stay within API query limits
    time.sleep(12)
    
    # Try and save the reviews to the reviews_list
    try:
        for review in reviews["response"]["docs"]:
            # loop through the reviews["response"]["docs"] and append each review to the list
            reviews_list.append(review)
        # Print the page that was just retrieved
        print(f"Checked page {page}")
        # Print the page number that had no results then break from the loop
    except:
        print(f"Failed on page {page}")
        break
# Out:
# Checked page 0
# Checked page 1
# Checked page 2
# Checked page 3
# Failed on page 4

# %%
# Preview the first 5 results in JSON format
# Use json.dumps with argument indent=4 to format data
print(json.dumps(reviews_list[0:5], indent=4))
# Out:
# [
#     {
#         "web_url": "https://www.nytimes.com/2023/05/25/movies/the-attachment-diaries-review.html",
#         "snippet": "A gynecologist and her patient form a horrifyingly twisted connection in this batty, bloody Argentine melodrama.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "\u2018The Attachment Diaries\u2019 Review: Love, Sick",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": "The Attachment Diaries",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "The Attachment Diaries (Movie)",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Diment, Valentin Javier",
#                 "rank": 3,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2023-05-25T11:00:03+0000",
#         "byline": {
#             "original": "By Jeannette Catsoulis",
#             "person": [
#                 {
#                     "firstname": "Jeannette",
#                     "middlename": null,
#                     "lastname": "Catsoulis",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 295
#     },
#     {
#         "web_url": "https://www.nytimes.com/2023/05/04/movies/whats-love-got-to-do-with-it-review.html",
#         "snippet": "Two childhood friends navigate cultural differences in this pleasantly uncontentious romantic comedy.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "Review: \u2018What\u2019s Love Got to Do With It?\u2019 Probably a Lot",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": "What\u2019s Love Got to Do With It?",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Kapur, Shekhar",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "James, Lily",
#                 "rank": 3,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Azmi, Shabana",
#                 "rank": 4,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Thompson, Emma",
#                 "rank": 5,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2023-05-04T17:16:45+0000",
#         "byline": {
#             "original": "By Jeannette Catsoulis",
#             "person": [
#                 {
#                     "firstname": "Jeannette",
#                     "middlename": null,
#                     "lastname": "Catsoulis",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 287
#     },
#     {
#         "web_url": "https://www.nytimes.com/2023/05/04/movies/you-can-live-forever-review.html",
#         "snippet": "Religion comes between two girls falling in love in the 1990s in this sweet coming-of-age film bathed in grunge hues.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "\u2018You Can Live Forever\u2019 Review: Do You Love Me Now?",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": "You Can Live Forever",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "You Can Live Forever (Movie)",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Slutsky, Mark",
#                 "rank": 3,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Watts, Sarah (Film Director)",
#                 "rank": 4,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "O'Driscoll, Anwen",
#                 "rank": 5,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Laporte, June (Actor)",
#                 "rank": 6,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2023-05-04T11:00:08+0000",
#         "byline": {
#             "original": "By Elisabeth Vincentelli",
#             "person": [
#                 {
#                     "firstname": "Elisabeth",
#                     "middlename": null,
#                     "lastname": "Vincentelli",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 294
#     },
#     {
#         "web_url": "https://www.nytimes.com/2023/04/21/movies/a-tourists-guide-to-love-review.html",
#         "snippet": "Rachael Leigh Cook stars in this bland rom-com as a travel executive exploring Vietnam and getting over a breakup.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "\u2018A Tourist\u2019s Guide to Love\u2019 Review: A Wearyingly Familiar Trip",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": "A Tourist\u2019s  Guide to Love",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "A Tourist's Guide to Love (Movie)",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Tsuchida, Steven",
#                 "rank": 3,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Cook, Rachael Leigh",
#                 "rank": 4,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2023-04-21T07:03:25+0000",
#         "byline": {
#             "original": "By Elisabeth Vincentelli",
#             "person": [
#                 {
#                     "firstname": "Elisabeth",
#                     "middlename": null,
#                     "lastname": "Vincentelli",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 276
#     },
#     {
#         "web_url": "https://www.nytimes.com/2023/04/20/movies/other-peoples-children-review.html",
#         "snippet": "A radiant Virginie Efira stars as a Parisian teacher who blissfully falls for a man and his 4-year-old daughter, complicating everyone\u2019s lives.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "\u2018Other People\u2019s Children\u2019 Review: True Romance",
#             "kicker": "Critic\u2019s pick",
#             "content_kicker": null,
#             "print_headline": "Intoxicating Love With a Sobering Turn",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Zlotowski, Rebecca",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "Other People's Children (Movie)",
#                 "rank": 3,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2023-04-20T15:35:13+0000",
#         "byline": {
#             "original": "By Manohla Dargis",
#             "person": [
#                 {
#                     "firstname": "Manohla",
#                     "middlename": null,
#                     "lastname": "Dargis",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 801
#     }
# ]

# %%
# Convert reviews_list to a Pandas DataFrame using json_normalize()
reviews_df = pd.json_normalize(reviews_list)
reviews_df.head()
# Out:
#                                              web_url  \
# 0  https://www.nytimes.com/2023/05/25/movies/the-...
# 1  https://www.nytimes.com/2023/05/04/movies/what...
# 2  https://www.nytimes.com/2023/05/04/movies/you-...
# 3  https://www.nytimes.com/2023/04/21/movies/a-to...
# 4  https://www.nytimes.com/2023/04/20/movies/othe...
#
#                                              snippet              source  \
# 0  A gynecologist and her patient form a horrifyi...  The New York Times
# 1  Two childhood friends navigate cultural differ...  The New York Times
# 2  Religion comes between two girls falling in lo...  The New York Times
# 3  Rachael Leigh Cook stars in this bland rom-com...  The New York Times
# 4  A radiant Virginie Efira stars as a Parisian t...  The New York Times
#
#                                             keywords  \
# 0  [{'name': 'subject', 'value': 'Movies', 'rank'...
# 1  [{'name': 'subject', 'value': 'Movies', 'rank'...
# 2  [{'name': 'subject', 'value': 'Movies', 'rank'...
# 3  [{'name': 'subject', 'value': 'Movies', 'rank'...
# 4  [{'name': 'subject', 'value': 'Movies', 'rank'...
#
#                    pub_date  word_count  \
# 0  2023-05-25T11:00:03+0000         295
# 1  2023-05-04T17:16:45+0000         287
# 2  2023-05-04T11:00:08+0000         294
# 3  2023-04-21T07:03:25+0000         276
# 4  2023-04-20T15:35:13+0000         801
#
#                                        headline.main headline.kicker  \
# 0        ‘The Attachment Diaries’ Review: Love, Sick            None
# 1  Review: ‘What’s Love Got to Do With It?’ Proba...            None
# 2  ‘You Can Live Forever’ Review: Do You Love Me ...            None
# 3  ‘A Tourist’s Guide to Love’ Review: A Wearying...            None
# 4     ‘Other People’s Children’ Review: True Romance   Critic’s pick
#
#   headline.content_kicker                 headline.print_headline  \
# 0                    None                  The Attachment Diaries
# 1                    None          What’s Love Got to Do With It?
# 2                    None                    You Can Live Forever
# 3                    None              A Tourist’s  Guide to Love
# 4                    None  Intoxicating Love With a Sobering Turn
#
#   headline.name headline.seo headline.sub           byline.original  \
# 0          None         None         None    By Jeannette Catsoulis
# 1          None         None         None    By Jeannette Catsoulis
# 2          None         None         None  By Elisabeth Vincentelli
# 3          None         None         None  By Elisabeth Vincentelli
# 4          None         None         None         By Manohla Dargis
#
#                                        byline.person byline.organization
# 0  [{'firstname': 'Jeannette', 'middlename': None...                None
# 1  [{'firstname': 'Jeannette', 'middlename': None...                None
# 2  [{'firstname': 'Elisabeth', 'middlename': None...                None
# 3  [{'firstname': 'Elisabeth', 'middlename': None...                None
# 4  [{'firstname': 'Manohla', 'middlename': None, ...                None

# %%
# Extract the title from the "headline.main" column and
# save it to a new column "title"
# Title is between unicode characters \u2018 and \u2019. 
# End string should include " Review" to avoid cutting title early
reviews_df["title"] = reviews_df["headline.main"].apply(
    lambda st: st[st.find("\u2018")+1:st.find("\u2019 Review")]
                                       )
reviews_df.head()
# Out:
#                                              web_url  \
# 0  https://www.nytimes.com/2023/05/25/movies/the-...
# 1  https://www.nytimes.com/2023/05/04/movies/what...
# 2  https://www.nytimes.com/2023/05/04/movies/you-...
# 3  https://www.nytimes.com/2023/04/21/movies/a-to...
# 4  https://www.nytimes.com/2023/04/20/movies/othe...
#
#                                              snippet              source  \
# 0  A gynecologist and her patient form a horrifyi...  The New York Times
# 1  Two childhood friends navigate cultural differ...  The New York Times
# 2  Religion comes between two girls falling in lo...  The New York Times
# 3  Rachael Leigh Cook stars in this bland rom-com...  The New York Times
# 4  A radiant Virginie Efira stars as a Parisian t...  The New York Times
#
#                                             keywords  \
# 0  [{'name': 'subject', 'value': 'Movies', 'rank'...
# 1  [{'name': 'subject', 'value': 'Movies', 'rank'...
# 2  [{'name': 'subject', 'value': 'Movies', 'rank'...
# 3  [{'name': 'subject', 'value': 'Movies', 'rank'...
# 4  [{'name': 'subject', 'value': 'Movies', 'rank'...
#
#                    pub_date  word_count  \
# 0  2023-05-25T11:00:03+0000         295
# 1  2023-05-04T17:16:45+0000         287
# 2  2023-05-04T11:00:08+0000         294
# 3  2023-04-21T07:03:25+0000         276
# 4  2023-04-20T15:35:13+0000         801
#
#                                        headline.main headline.kicker  \
# 0        ‘The Attachment Diaries’ Review: Love, Sick            None
# 1  Review: ‘What’s Love Got to Do With It?’ Proba...            None
# 2  ‘You Can Live Forever’ Review: Do You Love Me ...            None
# 3  ‘A Tourist’s Guide to Love’ Review: A Wearying...            None
# 4     ‘Other People’s Children’ Review: True Romance   Critic’s pick
#
#   headline.content_kicker                 headline.print_headline  \
# 0                    None                  The Attachment Diaries
# 1                    None          What’s Love Got to Do With It?
# 2                    None                    You Can Live Forever
# 3                    None              A Tourist’s  Guide to Love
# 4                    None  Intoxicating Love With a Sobering Turn
#
#   headline.name headline.seo headline.sub           byline.original  \
# 0          None         None         None    By Jeannette Catsoulis
# 1          None         None         None    By Jeannette Catsoulis
# 2          None         None         None  By Elisabeth Vincentelli
# 3          None         None         None  By Elisabeth Vincentelli
# 4          None         None         None         By Manohla Dargis
#
#                                        byline.person byline.organization  \
# 0  [{'firstname': 'Jeannette', 'middlename': None...                None
# 1  [{'firstname': 'Jeannette', 'middlename': None...                None
# 2  [{'firstname': 'Elisabeth', 'middlename': None...                None
# 3  [{'firstname': 'Elisabeth', 'middlename': None...                None
# 4  [{'firstname': 'Manohla', 'middlename': None, ...                None
#
#                                            title
# 0                         The Attachment Diaries
# 1  What’s Love Got to Do With It?’ Probably a Lo
# 2                           You Can Live Forever
# 3                      A Tourist’s Guide to Love
# 4                        Other People’s Children

# %%
# Extract 'name' and 'value' from items in "keywords" column
def extract_keywords(keyword_list):
    extracted_keywords = ""
    for item in keyword_list:
        # Extract 'name' and 'value'
        keyword = f"{item['name']}: {item['value']};" 
        # Append the keyword item to the extracted_keywords list
        extracted_keywords += keyword
    return extracted_keywords

# Fix the "keywords" column by converting cells from a list to a string
reviews_df["keywords"] = reviews_df["keywords"].apply(extract_keywords)
reviews_df.head()
# Out:
#                                              web_url  \
# 0  https://www.nytimes.com/2023/05/25/movies/the-...
# 1  https://www.nytimes.com/2023/05/04/movies/what...
# 2  https://www.nytimes.com/2023/05/04/movies/you-...
# 3  https://www.nytimes.com/2023/04/21/movies/a-to...
# 4  https://www.nytimes.com/2023/04/20/movies/othe...
#
#                                              snippet              source  \
# 0  A gynecologist and her patient form a horrifyi...  The New York Times
# 1  Two childhood friends navigate cultural differ...  The New York Times
# 2  Religion comes between two girls falling in lo...  The New York Times
# 3  Rachael Leigh Cook stars in this bland rom-com...  The New York Times
# 4  A radiant Virginie Efira stars as a Parisian t...  The New York Times
#
#                                             keywords  \
# 0  subject: Movies;creative_works: The Attachment...
# 1  subject: Movies;persons: Kapur, Shekhar;person...
# 2  subject: Movies;creative_works: You Can Live F...
# 3  subject: Movies;creative_works: A Tourist's Gu...
# 4  subject: Movies;persons: Zlotowski, Rebecca;cr...
#
#                    pub_date  word_count  \
# 0  2023-05-25T11:00:03+0000         295
# 1  2023-05-04T17:16:45+0000         287
# 2  2023-05-04T11:00:08+0000         294
# 3  2023-04-21T07:03:25+0000         276
# 4  2023-04-20T15:35:13+0000         801
#
#                                        headline.main headline.kicker  \
# 0        ‘The Attachment Diaries’ Review: Love, Sick            None
# 1  Review: ‘What’s Love Got to Do With It?’ Proba...            None
# 2  ‘You Can Live Forever’ Review: Do You Love Me ...            None
# 3  ‘A Tourist’s Guide to Love’ Review: A Wearying...            None
# 4     ‘Other People’s Children’ Review: True Romance   Critic’s pick
#
#   headline.content_kicker                 headline.print_headline  \
# 0                    None                  The Attachment Diaries
# 1                    None          What’s Love Got to Do With It?
# 2                    None                    You Can Live Forever
# 3                    None              A Tourist’s  Guide to Love
# 4                    None  Intoxicating Love With a Sobering Turn
#
#   headline.name headline.seo headline.sub           byline.original  \
# 0          None         None         None    By Jeannette Catsoulis
# 1          None         None         None    By Jeannette Catsoulis
# 2          None         None         None  By Elisabeth Vincentelli
# 3          None         None         None  By Elisabeth Vincentelli
# 4          None         None         None         By Manohla Dargis
#
#                                        byline.person byline.organization  \
# 0  [{'firstname': 'Jeannette', 'middlename': None...                None
# 1  [{'firstname': 'Jeannette', 'middlename': None...                None
# 2  [{'firstname': 'Elisabeth', 'middlename': None...                None
# 3  [{'firstname': 'Elisabeth', 'middlename': None...                None
# 4  [{'firstname': 'Manohla', 'middlename': None, ...                None
#
#                                            title
# 0                         The Attachment Diaries
# 1  What’s Love Got to Do With It?’ Probably a Lo
# 2                           You Can Live Forever
# 3                      A Tourist’s Guide to Love
# 4                        Other People’s Children

# %%
# Create a list from the "title" column using to_list()
# These titles will be used in the query for The Movie Database
titles = (reviews_df["title"]).to_list()
titles[0:10]
# Out:
# ['The Attachment Diaries',
#  'What’s Love Got to Do With It?’ Probably a Lo',
#  'You Can Live Forever',
#  'A Tourist’s Guide to Love',
#  'Other People’s Children',
#  'One True Loves',
#  'The Lost Weekend: A Love Story',
#  'A Thousand and One',
#  'Your Place or Mine',
#  'Love in the Time of Fentanyl']

# %% [markdown]
# ### Access The Movie Database API

# %%
# Prepare The Movie Database query
url = "https://api.themoviedb.org/3/search/movie?query="
tmdb_key_string = "&api_key=" + tmdb_api_key

# %%
# Create an empty list to store the results
tmdb_movies_list = []


# Create a request counter to sleep the requests after a multiple
# of 50 requests
request_counter = 1

# Loop through the titles
for title in titles:
    # Check if we need to sleep before making a request
    if request_counter % 50 == 0:
        time.sleep(1)
    # Add 1 to the request counter
    request_counter += 1
    
    # Perform a "GET" request for The Movie Database
    query_url = f"{url}{title}{tmdb_key_string}"
    reviews = requests.get(query_url).json()

    # Include a try clause to search for the full movie details.
    # Use the except clause to print out a statement if a movie
    # is not found.
    try:
        # Get movie id
        movie_id = reviews["results"][0]["id"]
        #print(movie_id)

        # Make a request for a the full movie detadils
        details_query_url = f"https://api.themoviedb.org/3/movie/{movie_id}?api_key={tmdb_api_key}"
        
        # Execute "GET" request with url
        details = requests.get(details_query_url).json()

        # Extract the genre names into a list
        genres = []
        #loop through each genre
        for genre in details["genres"]:
            genres.append(genre["name"])

        # Extract the spoken_languages' English name into a list
        spoken_languages = []
        for language in details["spoken_languages"]:
            spoken_languages.append(language["english_name"])

        # Extract the production_countries' name into a list
        production_countries = []
        for country in details["production_countries"]:
            production_countries.append(country["name"])

        # Add the relevant data to a dictionary and
        # append it to the tmdb_movies_list list
        results = {
                    "title" : details["title"], 
                   "original_title" : details["original_title"],
                   "budget" : details["budget"] ,
                   "original_language" : details["original_language"],
                   "homepage" : details["homepage"], 
                   "overview" : details["overview"], 
                   "popularity" : details["popularity"], 
                   "runtime" : details["runtime"], 
                   "revenue" : details["revenue"], 
                   "release_date" : details["release_date"], 
                   "vote_average" : details["vote_average"], 
                   "vote_count" : details["vote_count"],
                   "genres" : genres,
                   "spoken_languages" : spoken_languages,
                   "production_countries" : production_countries  
        }
        tmdb_movies_list.append(results)
        # Print out the title that was found
        print(f"{title} was found")
    except:
        print(f"{title} was not found")
# Out:
# The Attachment Diaries was found
# What’s Love Got to Do With It?’ Probably a Lo was not found
# You Can Live Forever was found
# A Tourist’s Guide to Love was found
# Other People’s Children was found
# One True Loves was found
# The Lost Weekend: A Love Story was found
# A Thousand and One was found
# Your Place or Mine was found
# Love in the Time of Fentanyl was found
# Pamela, a Love Story was found
# In From the Side was found
# After Love was found
# Alcarràs was found
# Nelly & Nadine was found
# Lady Chatterley’s Lover was found
# The Sound of Christmas was found
# The Inspection was found
# Bones and All was found
# My Policeman was found
# About Fate was found
# Waiting for Bojangles was found
# I Love My Dad was found
# A Love Song was found
# Alone Together was found
# Art of Love was found
# The Wheel was found
# Thor: Love and Thunder was found
# Both Sides of the Blade was found
# Fire of Love was found
# Love & Gelato was found
# Stay Prayed Up was found
# Benediction was found
# Dinner in America was found
# In a New York Minute was found
# Anaïs in Love was found
# I Love America was found
# See You Then was found
# La Mami was found
# Love After Love was found

# %%
# Preview the first 5 results in JSON format
# Use json.dumps with argument indent=4 to format data
print(json.dumps(tmdb_movies_list[:5], indent=4))
# Out:
# [
#     {
#         "title": "The Attachment Diaries",
#         "original_title": "El apego",
#         "budget": 0,
#         "original_language": "es",
#         "homepage": "",
#         "overview": "Argentina, 1970s. A desperate young woman goes to a clinic to have a clandestine abortion. As her pregnancy is already through the fourth month, the doctor refuses. Instead, she proposes to sell the baby to one of her clients and offers to provide shelter in her house until the child is born. Their disturbed personalities will become intertwined in a strange and dangerous relationship.",
#         "popularity": 1.403,
#         "runtime": 102,
#         "revenue": 0,
#         "release_date": "2021-10-07",
#         "vote_average": 4.0,
#         "vote_count": 2,
#         "genres": [
#             "Drama",
#             "Mystery",
#             "Thriller",
#             "Horror"
#         ],
#         "spoken_languages": [
#             "Spanish"
#         ],
#         "production_countries": [
#             "Argentina"
#         ]
#     },
#     {
#         "title": "You Can Live Forever",
#         "original_title": "You Can Live Forever",
#         "budget": 0,
#         "original_language": "en",
#         "homepage": "https://gooddeedentertainment.com/you-can-live-forever/",
#         "overview": "When Jaime, a gay teenager, is sent to live in a community of Jehovah's Witnesses in small-town Quebec, she falls madly in love with a devout Witness girl. The two embark on an intense affair with consequences that will reshape the rest of their lives.",
#         "popularity": 8.527,
#         "runtime": 96,
#         "revenue": 0,
#         "release_date": "2022-06-11",
#         "vote_average": 7.3,
#         "vote_count": 38,
#         "genres": [
#             "Drama",
#             "Romance"
#         ],
#         "spoken_languages": [
#             "French",
#             "English"
#         ],
#         "production_countries": [
#             "Canada"
#         ]
#     },
#     {
#         "title": "A Tourist's Guide to Love",
#         "original_title": "A Tourist's Guide to Love",
#         "budget": 0,
#         "original_language": "en",
#         "homepage": "https://www.netflix.com/title/81424906",
#         "overview": "After an unexpected break up, a travel executive accepts an assignment to go undercover and learn about the tourist industry in Vietnam. Along the way, she finds adventure and romance with her Vietnamese expat tour guide and they decide to hijack the tour bus in order to explore life and love off the beaten path.",
#         "popularity": 14.099,
#         "runtime": 96,
#         "revenue": 0,
#         "release_date": "2023-04-21",
#         "vote_average": 6.4,
#         "vote_count": 138,
#         "genres": [
#             "Romance",
#             "Comedy",
#             "Adventure"
#         ],
#         "spoken_languages": [
#             "English"
#         ],
#         "production_countries": [
#             "United States of America"
#         ]
#     },
#     {
#         "title": "Other People's Children",
#         "original_title": "Les Enfants des autres",
#         "budget": 0,
#         "original_language": "fr",
#         "homepage": "https://www.wildbunch.biz/movie/other-peoples-children/",
#         "overview": "Rachel loves her life, her students, her friends, her ex, her guitar lessons. When she falls in love with Ali, she grows close to his 4-year-old daughter, Leila. She tucks her in, looks after her, and loves her like a mother... which she isn\u2019t. Not yet. Rachel is 40. The desire for a family of her own is growing stronger, and the clock is ticking. Is it too late?",
#         "popularity": 11.041,
#         "runtime": 104,
#         "revenue": 0,
#         "release_date": "2022-09-21",
#         "vote_average": 6.911,
#         "vote_count": 157,
#         "genres": [
#             "Drama"
#         ],
#         "spoken_languages": [
#             "French"
#         ],
#         "production_countries": [
#             "France"
#         ]
#     },
#     {
#         "title": "One True Loves",
#         "original_title": "One True Loves",
#         "budget": 0,
#         "original_language": "en",
#         "homepage": "",
#         "overview": "Emma and Jesse are living the perfect life together, until Jesse disappears in a tragic helicopter crash on their first wedding anniversary. Four years later, Emma has found happiness again and is about to marry her best friend when Jesse resurfaces, turning her world upside down and leaving her torn between two great loves.",
#         "popularity": 13.049,
#         "runtime": 100,
#         "revenue": 37820,
#         "release_date": "2023-04-07",
#         "vote_average": 6.8,
#         "vote_count": 47,
#         "genres": [
#             "Romance",
#             "Drama",
#             "Comedy"
#         ],
#         "spoken_languages": [
#             "English"
#         ],
#         "production_countries": [
#             "Germany",
#             "United States of America"
#         ]
#     }
# ]

# %%
# Convert the results to a DataFrame
tmdb_df = pd.DataFrame(tmdb_movies_list)
tmdb_df.dtypes
# Out:
# title                    object
# original_title           object
# budget                    int64
# original_language        object
# homepage                 object
# overview                 object
# popularity              float64
# runtime                   int64
# revenue                   int64
# release_date             object
# vote_average            float64
# vote_count                int64
# genres                   object
# spoken_languages         object
# production_countries     object
# dtype: object

# %% [markdown]
# ### Merge and Clean the Data for Export

# %%
# Merge the New York Times reviews and TMDB DataFrames on title
merged_df = pd.merge(reviews_df, tmdb_df, on= "title")
merged_df.head()
# Out:
#                                              web_url  \
# 0  https://www.nytimes.com/2023/05/25/movies/the-...
# 1  https://www.nytimes.com/2023/05/04/movies/you-...
# 2  https://www.nytimes.com/2023/04/13/movies/one-...
# 3  https://www.nytimes.com/2023/04/13/movies/the-...
# 4  https://www.nytimes.com/2023/03/30/movies/a-th...
#
#                                              snippet              source  \
# 0  A gynecologist and her patient form a horrifyi...  The New York Times
# 1  Religion comes between two girls falling in lo...  The New York Times
# 2  A film adaptation of Taylor Jenkins Reid’s nov...  The New York Times
# 3  There’s not much Lennon music heard in this do...  The New York Times
# 4  A mesmerizing Teyana Taylor stars in A.V. Rock...  The New York Times
#
#                                             keywords  \
# 0  subject: Movies;creative_works: The Attachment...
# 1  subject: Movies;creative_works: You Can Live F...
# 2  subject: Movies;persons: Bracey, Luke (1989- )...
# 3  subject: Documentary Films and Programs;creati...
# 4  subject: Movies;creative_works: A Thousand and...
#
#                    pub_date  word_count  \
# 0  2023-05-25T11:00:03+0000         295
# 1  2023-05-04T11:00:08+0000         294
# 2  2023-04-13T11:00:06+0000         320
# 3  2023-04-13T11:00:03+0000         327
# 4  2023-03-30T18:53:42+0000         971
#
#                                        headline.main headline.kicker  \
# 0        ‘The Attachment Diaries’ Review: Love, Sick            None
# 1  ‘You Can Live Forever’ Review: Do You Love Me ...            None
# 2     ‘One True Loves’ Review: A Romance Lost at Sea            None
# 3  ‘The Lost Weekend: A Love Story’ Review: When ...            None
# 4  ‘A Thousand and One’ Review: A New York Love S...   Critic’s Pick
#
#   headline.content_kicker                  headline.print_headline  ...  \
# 0                    None                   The Attachment Diaries  ...
# 1                    None                     You Can Live Forever  ...
# 2                    None                           One True Loves  ...
# 3                    None          The Lost Weekend:  A Love Story  ...
# 4                    None  An Unbending Will Meets a Shifting City  ...
#
#                                             overview popularity runtime  \
# 0  Argentina, 1970s. A desperate young woman goes...      1.403     102
# 1  When Jaime, a gay teenager, is sent to live in...      8.527      96
# 2  Emma and Jesse are living the perfect life tog...     13.049     100
# 3  May Pang lovingly recounts her life in rock & ...      3.677      95
# 4  Struggling but unapologetically living on her ...     14.085     116
#
#   revenue release_date vote_average vote_count  \
# 0       0   2021-10-07          4.0          2
# 1       0   2022-06-11          7.3         38
# 2   37820   2023-04-07          6.8         47
# 3       0   2023-04-13          6.0          2
# 4       0   2023-03-31          7.0         50
#
#                                genres   spoken_languages  \
# 0  [Drama, Mystery, Thriller, Horror]          [Spanish]
# 1                    [Drama, Romance]  [French, English]
# 2            [Romance, Drama, Comedy]          [English]
# 3                       [Documentary]          [English]
# 4                             [Drama]          [English]
#
#                   production_countries
# 0                          [Argentina]
# 1                             [Canada]
# 2  [Germany, United States of America]
# 3           [United States of America]
# 4           [United States of America]
#
# [5 rows x 31 columns]

# %%
# Remove list brackets and quotation marks on the columns containing lists
# Create a list of the columns that need fixing
columns_to_fix = ["genres", "spoken_languages", "production_countries"]

# Create a list of characters to remove
characters_to_remove = ["[", "]", "'"]

# Loop through the list of columns to fix
for column in columns_to_fix:
    # Convert the column to type 'str'
    merged_df = merged_df.astype({column: 'str'})
    # Loop through characters to remove
    for character in characters_to_remove:
        merged_df[column] = merged_df[column].str.replace(character, " ", regex=False)
        

# Display the fixed DataFrame
merged_df
# Out:
#                                               web_url  \
# 0   https://www.nytimes.com/2023/05/25/movies/the-...
# 1   https://www.nytimes.com/2023/05/04/movies/you-...
# 2   https://www.nytimes.com/2023/04/13/movies/one-...
# 3   https://www.nytimes.com/2023/04/13/movies/the-...
# 4   https://www.nytimes.com/2023/03/30/movies/a-th...
# 5   https://www.nytimes.com/2023/02/09/movies/your...
# 6   https://www.nytimes.com/2023/02/02/movies/love...
# 7   https://www.nytimes.com/2023/01/19/movies/afte...
# 8   https://www.nytimes.com/2023/01/05/movies/alca...
# 9   https://www.nytimes.com/2022/11/23/movies/soun...
# 10  https://www.nytimes.com/2022/11/17/movies/the-...
# 11  https://www.nytimes.com/2022/11/17/movies/bone...
# 12  https://www.nytimes.com/2022/10/20/movies/my-p...
# 13  https://www.nytimes.com/2022/09/08/movies/abou...
# 14  https://www.nytimes.com/2022/09/01/movies/wait...
# 15  https://www.nytimes.com/2022/08/04/movies/i-lo...
# 16  https://www.nytimes.com/2022/07/28/movies/a-lo...
# 17  https://www.nytimes.com/2022/07/21/movies/alon...
# 18  https://www.nytimes.com/2022/07/07/movies/thor...
# 19  https://www.nytimes.com/2022/07/07/movies/both...
# 20  https://www.nytimes.com/2022/07/06/movies/fire...
# 21  https://www.nytimes.com/2022/06/16/movies/stay...
# 22  https://www.nytimes.com/2022/06/02/movies/bene...
# 23  https://www.nytimes.com/2022/05/26/movies/dinn...
# 24  https://www.nytimes.com/2022/05/03/movies/in-a...
# 25  https://www.nytimes.com/2022/04/28/movies/anai...
# 26  https://www.nytimes.com/2022/04/28/movies/i-lo...
# 27  https://www.nytimes.com/2022/04/18/movies/see-...
# 28  https://www.nytimes.com/2022/04/07/movies/la-m...
# 29  https://www.nytimes.com/2022/03/17/movies/love...
#
#                                               snippet              source  \
# 0   A gynecologist and her patient form a horrifyi...  The New York Times
# 1   Religion comes between two girls falling in lo...  The New York Times
# 2   A film adaptation of Taylor Jenkins Reid’s nov...  The New York Times
#
# 8                     None                                           Alcarràs
# 9                     None                            The Sound  Of Christmas
# 10                    None                  A Few Good Men, Some With Secrets
# 11                    None  It’s Eat, Prey, Love on a Journey of Self-Disc...
# 12                    None                                       My Policeman
# 13                    None                                         About Fate
# 14                    None                              Waiting for Bojangles
# 15                    None  A Father Catfishes His Son. We Just Wait for t...
# 16                    None            The Romantic Ache That Never Truly Dies
# 17                    None                                     Alone Together
# 18                    None    He’s Still a Norse God, But Also a Big Old Goof
# 19                    None                        A Bliss Doomed To Be Doused
# 20                    None               A Volcanic Romance Across Continents
# 21                    None                                     Stay Prayed Up
# 22                    None                     A Poet’s Life, In Love and War
# 23                    None                                  Dinner in America
# 24                    None                               In a New York Minute
# 25                    None                       Portrait of a Restless Heart
# 26                    None                                     I Love America
# 27                    None                  The Persistent Melancholy of Love
# 28                    None                                            La Mami
# 29                    None                                    Love After Love
#
#     ...                                           overview popularity runtime  \
# 0   ...  Argentina, 1970s. A desperate young woman goes...      1.403     102
# 1   ...  When Jaime, a gay teenager, is sent to live in...      8.527      96
# 2   ...  Emma and Jesse are living the perfect life tog...     13.049     100
# 3   ...  May Pang lovingly recounts her life in rock & ...      3.677      95
# 4   ...  Struggling but unapologetically living on her ...     14.085     116
# 5   ...  When best friends and total opposites Debbie a...     22.544     109
# 6   ...  An intimate portrait of a community fighting t...      6.419      85
# 7   ...  Set in the port town of Dover in the South-Eas...      7.621      89
# 8   ...  In a small village in Catalonia, the peach far...      9.183     120
# 9   ...  A woman facing eviction just before Christmas ...      2.993       0
# 10  ...  Ellis French is a young, gay Black man, reject...     11.000      95
# 11  ...  Abandoned by her father, a young woman embarks...     20.388     131
# 12  ...  In the late 1990s, the arrival of elderly inva...     14.640     113
# 13  ...  Two strangers believe in love but never seem t...     18.425     100
# 14  ...  A boy and his eccentric parents leave their ho...     15.869     124
# 15  ...  A hopelessly estranged father catfishes his so...     11.955      90
# 16  ...  Two childhood sweethearts, now both widowed, s...      6.582      81
# 17  ...  Strangers June and Charlie wind up double-book...      5.287     101
# 18  ...  After his retirement is interrupted by Gorr th...    118.449     119
# 19  ...  Jean and Sara have been living together for 10...      7.391     117
# 20  ...  A doomed love triangle between intrepid French...      9.878      93
# 21  ...  Lena Mae “Mother” Perry, the backbone of her c...      0.600      73
# 22  ...  Poet Siegfried Sassoon survived the horrors of...      8.130     137
# 23  ...  An on-the-lam punk rocker and a young woman ob...     12.022     106
# 24  ...  In A New York Minute follows three Asian women...      2.744     102
# 25  ...  A young woman struggling to stay on top of eve...      8.752      98
# 26  ...  A single woman who decides to take a chance on...      6.949     102
# 27  ...  A decade after abruptly breaking up with Naomi...      1.767      74
# 28  ...  One of the rooms inside the legendary Barba Az...      0.748      82
# 29  ...  A sixty-something mother and her two adult son...      1.687      93
#
#       revenue release_date vote_average vote_count  \
# 0           0   2021-10-07        4.000          2
# 1           0   2022-06-11        7.300         38
# 2       37820   2023-04-07        6.800         47
# 3           0   2023-04-13        6.000          2
# 4           0   2023-03-31        7.000         50
# 5           0   2023-02-10        6.310        628
# 6           0   2023-02-03        0.000          0
# [30 rows x 30 columns]

# %%
# Drop "byline.person" column
try:
    del merged_df["byline.person"]
except KeyError:
    print("Column already deleted")
merged_df.columns
# Out:
# Index(['web_url', 'snippet', 'source', 'keywords', 'pub_date', 'word_count',
#        'headline.main', 'headline.kicker', 'headline.content_kicker',
#        'headline.print_headline', 'headline.name', 'headline.seo',
#        'headline.sub', 'byline.original', 'byline.organization', 'title',
#        'original_title', 'budget', 'original_language', 'homepage', 'overview',
#        'popularity', 'runtime', 'revenue', 'release_date', 'vote_average',
#        'vote_count', 'genres', 'spoken_languages', 'production_countries'],
#       dtype='object')

# %%
# Delete duplicate rows and reset index
merged_df.drop_duplicates().reset_index(drop=True)
# Out:
#                                               web_url  \
# 0   https://www.nytimes.com/2023/05/25/movies/the-...
# 1   https://www.nytimes.com/2023/05/04/movies/you-...
# 2   https://www.nytimes.com/2023/04/13/movies/one-...
# 3   https://www.nytimes.com/2023/04/13/movies/the-...
# 4   https://www.nytimes.com/2023/03/30/movies/a-th...
# 5   https://www.nytimes.com/2023/02/09/movies/your...
# 6   https://www.nytimes.com/2023/02/02/movies/love...
# 7   https://www.nytimes.com/2023/01/19/movies/afte...
# 8   https://www.nytimes.com/2023/01/05/movies/alca...
# 9   https://www.nytimes.com/2022/11/23/movies/soun...
# 10  https://www.nytimes.com/2022/11/17/movies/the-...
# 11  https://www.nytimes.com/2022/11/17/movies/bone...
# 12  https://www.nytimes.com/2022/10/20/movies/my-p...
# 13  https://www.nytimes.com/2022/09/08/movies/abou...
# 14  https://www.nytimes.com/2022/09/01/movies/wait...
# 15  https://www.nytimes.com/2022/08/04/movies/i-lo...
# 16  https://www.nytimes.com/2022/07/28/movies/a-lo...
# 17  https://www.nytimes.com/2022/07/21/movies/alon...
# 18  https://www.nytimes.com/2022/07/07/movies/thor...
# 19  https://www.nytimes.com/2022/07/07/movies/both...
# 20  https://www.nytimes.com/2022/07/06/movies/fire...
# 21  https://www.nytimes.com/2022/06/16/movies/stay...
# 22  https://www.nytimes.com/2022/06/02/movies/bene...
# 23  https://www.nytimes.com/2022/05/26/movies/dinn...
# 24  https://www.nytimes.com/2022/05/03/movies/in-a...
# 25  https://www.nytimes.com/2022/04/28/movies/anai...
# 26  https://www.nytimes.com/2022/04/28/movies/i-lo...
# 27  https://www.nytimes.com/2022/04/18/movies/see-...
# 28  https://www.nytimes.com/2022/04/07/movies/la-m...
# 29  https://www.nytimes.com/2022/03/17/movies/love...
#
#                                               snippet              source  \
# 0   A gynecologist and her patient form a horrifyi...  The New York Times
# 1   Religion comes between two girls falling in lo...  The New York Times
# 2   A film adaptation of Taylor Jenkins Reid’s nov...  The New York Times
# 3   There’s not much Lennon music heard in this do...  The New York Times
# 4   A mesmerizing Teyana Taylor stars in A.V. Rock...  The New York Times
# 5   This humdrum Netflix romantic comedy features ...  The New York Times
# 6   To combat the overdose crisis, a group that in...  The New York Times
# 7   In this intelligent melodrama by the director ...  The New York Times
# 8   In this naturalistic drama from Spain, a famil...  The New York Times
# 9   A young singer gets more than she bargained fo...  The New York Times
# 10  Elegance Bratton’s autobiographical first feat...  The New York Times
# 11                    None  It’s Eat, Prey, Love on a Journey of Self-Disc...
# 12                    None                                       My Policeman
# 13                    None                                         About Fate
# 14                    None                              Waiting for Bojangles
# 15                    None  A Father Catfishes His Son. We Just Wait for t...
# 16                    None            The Romantic Ache That Never Truly Dies
# 17                    None                                     Alone Together
# 18                    None    He’s Still a Norse God, But Also a Big Old Goof
# 19                    None                        A Bliss Doomed To Be Doused
# 20                    None               A Volcanic Romance Across Continents
# 21                    None                                     Stay Prayed Up
# 22                    None                     A Poet’s Life, In Love and War
# 23                    None                                  Dinner in America
# 24                    None                               In a New York Minute
# 25                    None                       Portrait of a Restless Heart
# 26                    None                                     I Love America
# 27                    None                  The Persistent Melancholy of Love
# 28                    None                                            La Mami
# 29                    None                                    Love After Love
#
#     ...                                           overview popularity runtime  \
# 0   ...  Argentina, 1970s. A desperate young woman goes...      1.403     102
# 1   ...  When Jaime, a gay teenager, is sent to live in...      8.527      96
# 2   ...  Emma and Jesse are living the perfect life tog...     13.049     100
# 3   ...  May Pang lovingly recounts her life in rock & ...      3.677      95
# 4   ...  Struggling but unapologetically living on her ...     14.085     116
# 5   ...  When best friends and total opposites Debbie a...     22.544     109
# 6   ...  An intimate portrait of a community fighting t...      6.419      85
# 7   ...  Set in the port town of Dover in the South-Eas...      7.621      89
# 8   ...  In a small village in Catalonia, the peach far...      9.183     120
# 9   ...  A woman facing eviction just before Christmas ...      2.993       0
# 10  ...  Ellis French is a young, gay Black man, reject...     11.000      95
# 11  ...  Abandoned by her father, a young woman embarks...     20.388     131
# 12  ...  In the late 1990s, the arrival of elderly inva...     14.640     113
# 13  ...  Two strangers believe in love but never seem t...     18.425     100
# 14  ...  A boy and his eccentric parents leave their ho...     15.869     124
# 15  ...  A hopelessly estranged father catfishes his so...     11.955      90
# 16  ...  Two childhood sweethearts, now both widowed, s...      6.582      81
# 17  ...  Strangers June and Charlie wind up double-book...      5.287     101
# 18  ...  After his retirement is interrupted by Gorr th...    118.449     119
# 19  ...  Jean and Sara have been living together for 10...      7.391     117
# 20  ...  A doomed love triangle between intrepid French...      9.878      93
# 21  ...  Lena Mae “Mother” Perry, the backbone of her c...      0.600      73
# 22  ...  Poet Siegfried Sassoon survived the horrors of...      8.130     137
# 23  ...  An on-the-lam punk rocker and a young woman ob...     12.022     106
# 24  ...  In A New York Minute follows three Asian women...      2.744     102
# 25  ...  A young woman struggling to stay on top of eve...      8.752      98
# 26  ...  A single woman who decides to take a chance on...      6.949     102
# 27  ...  A decade after abruptly breaking up with Naomi...      1.767      74
# 28  ...  One of the rooms inside the legendary Barba Az...      0.748      82
# 29  ...  A sixty-something mother and her two adult son...      1.687      93
#
#       revenue release_date vote_average vote_count  \
# 0           0   2021-10-07        4.000          2
# 1           0   2022-06-11        7.300         38
# 2       37820   2023-04-07        6.800         47
# 3           0   2023-04-13        6.000          2
# 4           0   2023-03-31        7.000         50
# 5           0   2023-02-10        6.310        628
# 6           0   2023-02-03        0.000          0
# 7           0   2021-06-04        7.300         90
# 8           0   2022-04-29        6.901        157
# 9           0   2022-11-24        8.000          4
# 10          0   2022-11-18        6.400         45
# 11   15100000   2022-11-18        7.127       1074
# 12          0   2022-10-20        7.765        594
# 13          0   2022-09-08        7.444        277
# 14          0   2021-10-13        7.400        276
# 15          0   2022-08-05        5.800         40
# 16          0   2022-07-29        7.000         30
# 17          0   2022-07-22        5.100         30
# 18  760928081   2022-07-06        6.501       6702
# 19    1747438   2022-07-08        5.712         66
# 20          0   2022-07-06        7.500        171
# 21          0   2021-09-01        0.000          0
# 22     847418   2021-12-23        6.500         42
# 23          0   2020-05-27        6.800         72
# 24          0   2019-04-28        5.500          1
# 25          0   2021-09-15        6.200        128
# 26          0   2022-03-11        5.200         70
# 27          0   2022-04-01        2.500          2
# 28          0   2020-01-27        6.200          4
# 29          0   2018-03-30        5.600         19
#
#                                         genres  \
# 0     Drama ,  Mystery ,  Thriller ,  Horror
# 1                           Drama ,  Romance
# 2                 Romance ,  Drama ,  Comedy
# 3                                Documentary
# 4                                      Drama
# 5                          Romance ,  Comedy
# 6                                Documentary
# 7                                      Drama
# 8                                      Drama
# 9                          TV Movie ,  Drama
# 10                                     Drama
# 11                Drama ,  Horror ,  Romance
# 12                          Drama ,  Romance
# 13                         Romance ,  Comedy
# 14                Drama ,  Comedy ,  Romance
# 15                                    Comedy
# 16                          Drama ,  Romance
# 17                          Romance ,  Drama
# 18               Fantasy ,  Action ,  Comedy
# 19                          Drama ,  Romance
# 20                               Documentary
# 21                               Documentary
# 22                   Drama ,  History ,  War
# 23       Comedy ,  Drama ,  Music ,  Romance
# 24                                     Drama
# 25                Drama ,  Romance ,  Comedy
# 26                         Comedy ,  Romance
# 27                                     Drama
# 28                               Documentary
# 29                                     Drama
#
#                            spoken_languages  \
# 0                                 Spanish
# 1                       French ,  English
# 2                                 English
# 3                                 English
# 4                                 English
# 5                                 English
# 6                                 English
# 7     English ,  Arabic ,  French ,  Urdu
# 8                                 Catalan
# 9                                 English
# 10           Arabic ,  Spanish ,  English
# 11                                English
# 12                                English
# 13                                English
# 14                      French ,  English
# 15                                English
# 16                                English
# 17                                English
# 18                                English
# 19                                 French
# 20           Spanish ,  French ,  English
# 21
# 22            German ,  English ,  French
# 23                                English
# 24                                English
# 25                                 French
# 26                                 French
# 27                                English
# 28                                Spanish
# 29                                English
#
#                               production_countries
# 0                                      Argentina
# 1                                         Canada
# 2            Germany ,  United States of America
# 3                       United States of America
# 4                       United States of America
# 5                       United States of America
# 6             Canada ,  United States of America
# 7                                 United Kingdom
# 8                                          Spain
# 9                       United States of America
# 10                      United States of America
# 11             Italy ,  United States of America
# 12    United Kingdom ,  United States of America
# 13                      United States of America
# 14            France ,  United States of America
# 15                      United States of America
# 16                      United States of America
# 17                      United States of America
# 18                      United States of America
# 19                                        France
# 20            Canada ,  United States of America
# 21
# 22    United Kingdom ,  United States of America
# 23                      United States of America
# 24
# 25                                        France
# 26                      United States of America
# 27                      United States of America
# 28                               Mexico ,  Spain
# 29                      United States of America
#
# [30 rows x 30 columns]

# %%
# Export data to CSV without the index
merged_df.to_csv("NYT_and_TMDB_merged_reviews.csv", index=False)
